# %%
# !git clone --recursive https://github.com/sshaoshuai/PointRCNN.git

# %%
# %cd PointRCNN
# !pip install easydict
# !pip install tqdm
# !pip install tensorboardX
# !sudo apt-get install python3 python-dev python3-dev \
     build-essential libssl-dev libffi-dev \
     libxml2-dev libxslt1-dev zlib1g-dev \
     python-pip
import torch
import sys
'''
egg_path='/usr/local/lib/python3.6/dist-packages/pointnet2-0.0.0-py3.6-linux-x86_64.egg'
sys.path.append(egg_path)
egg_path='/usr/local/lib/python3.6/dist-packages/roipool3d-0.0.0-py3.6-linux-x86_64.egg'
sys.path.append(egg_path)
egg_path='/usr/local/lib/python3.6/dist-packages/iou3d-0.0.0-py3.6-linux-x86_64.egg'
sys.path.append(egg_path)
import pointnet2_cuda
import roipool3d_cuda
import iou3d_cuda
'''
# !chmod 777 build_and_install.sh
# !pwd

# %%
# !gcc --version
# !pwd
# !sudo apt install g++-5
# !sudo apt install gcc-5
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !sudo update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !sudo update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20
# !sudo update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !sudo update-alternatives --set cc /usr/bin/gcc
# !sudo update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !sudo update-alternatives --set c++ /usr/bin/g++

# %%
# !sudo apt-get install libblas-dev libatlas-base-dev lib32ncurses5-dev
# !apt-get install build-essential
# !sudo apt-get install build-essential autoconf libtool pkg-config python-opengl python-pil python-pyrex python-pyside.qtopengl idle-python2.7 qt4-dev-tools qt4-designer libqtgui4 libqtcore4 libqt4-xml libqt4-test libqt4-script libqt4-network libqt4-dbus python-qt4 python-qt4-gl libgle3 python-dev libssl-dev

# !sudo easy_install greenlet

# !sudo easy_install gevent
# !pip install easydict
# !pip install tqdm
# !pip install tensorboardX
import easydict
import tqdm
import tensorboardX
# %cd /content/PointRCNN
# !gcc --version
# !pwd

import torch
# %cd pointnet2_lib/pointnet2
# !python setup.py install
# %cd ../../

# %cd lib/utils/iou3d/
# !python setup.py install

# %cd ../roipool3d/
# !python setup.py install

# %cd ../../../tools

# %%
#!pip install torch==1.5.0
#!conda install pytorch==1.0.0 torchvision==0.2.1 -c pytorch
# !pip install torch==1.0.0 torchvision==0.2.1
# !pip install ninja
import torch
print(torch.__version__)

# %cd /content/PointRCNN

import torch
# %cd pointnet2_lib/pointnet2
import torch
# !python3 setup.py install
# %cd ../../

# %cd lib/utils/iou3d/
import torch
# !python3 setup.py install

# %cd ../roipool3d/
import torch
# !python3 setup.py install

# %cd ../../../tools

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip

# %%
# !pwd
# !pip install fire
# !python eval_rcnn.py --cfg_file cfgs/default.yaml --ckpt PointRCNN.pth --batch_size 1 --eval_mode rcnn --set RPN.LOC_XZ_FINE False
# Out:
# /content/PointRCNN/tools
# ...
# 2021-11-01 02:41:23,319   INFO  **********************Start logging**********************
# 2021-11-01 02:41:23,319   INFO  cfg_file         cfgs/default.yaml
# 2021-11-01 02:41:23,319   INFO  eval_mode        rcnn
# 2021-11-01 02:41:23,320   INFO  eval_all         False
# 2021-11-01 02:41:23,320   INFO  test             False
# 2021-11-01 02:41:23,320   INFO  ckpt             PointRCNN.pth
# 2021-11-01 02:41:23,320   INFO  rpn_ckpt         None
# 2021-11-01 02:41:23,320   INFO  rcnn_ckpt        None
# 2021-11-01 02:41:23,320   INFO  batch_size       1
# 2021-11-01 02:41:23,320   INFO  workers          4
# 2021-11-01 02:41:23,320   INFO  extra_tag        default
# 2021-11-01 02:41:23,320   INFO  output_dir       None
# 2021-11-01 02:41:23,320   INFO  ckpt_dir         None
# 2021-11-01 02:41:23,320   INFO  save_result      False
# 2021-11-01 02:41:23,320   INFO  save_rpn_feature False
# 2021-11-01 02:41:23,320   INFO  random_select    True
# ...
